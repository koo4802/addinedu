# %%
import pandas as pd

raw_data = pd.read_csv('../data/undong.csv', header=1)
raw_data
# Out:
#       시점 구분별(1)        구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  \
# 0   2019    서울시            소계               46.8               5.0
# 1   2019     성별            남자               52.4               4.4
# 2   2019     성별            여자               42.5               5.6
# 3   2019    연령별           10대               55.3               4.8
# 4   2019    연령별           20대               46.0               4.2
# 5   2019    연령별           30대               59.9               5.2
# 6   2019    연령별           40대               54.1               3.9
# 7   2019    연령별           50대               46.1               6.2
# 8   2019    연령별        60대 이상               26.6               6.0
# 9   2019    학력별         중졸 이하               24.7               6.2
# 10  2019    학력별         고졸 이하               44.3               5.3
# 11  2019    학력별         대졸 이하               53.1               4.7
# 12  2019    학력별        대학원 이상               61.2               3.0
# 13  2019    소득별      100만원 미만               10.7               8.4
# 14  2019    소득별  100-200만원 미만               29.6               5.6
# 15  2019    소득별  200-300만원 미만               42.8               7.3
# 16  2019    소득별  300-400만원 미만               50.6               4.3
# 17  2019    소득별  400-500만원 미만               48.0               4.6
# 18  2019    소득별      500만원 이상               52.8               4.3
# 19  2019  혼인상태별            기혼               48.7               4.5
# 20  2019  혼인상태별            미혼               50.2               4.9
# 21  2019  혼인상태별      이혼/사별/기타               31.5               7.2
# 22  2019  지역대분류           도심권               53.8               3.8
# 23  2019  지역대분류           동북권               44.5               3.5
# 24  2019  지역대분류           서북권               50.7               6.6
# 25  2019  지역대분류           서남권               47.1               6.7
# 26  2019  지역대분류           동남권               46.3               4.7
# 27  2019  지역소분류           종로구               62.2               0.4
# 28  2019  지역소분류            중구               50.3               3.0
# 29  2019  지역소분류           용산구               48.9               7.5
# 30  2019  지역소분류           성동구               46.5               4.3
# 31  2019  지역소분류           광진구               42.0               5.7
# 32  2019  지역소분류          동대문구               44.5               4.5
# 33  2019  지역소분류           중랑구               46.7               2.2
# 34  2019  지역소분류           성북구               33.3               3.4
# 35  2019  지역소분류           강북구               21.3               5.3
# 36  2019  지역소분류           도봉구               52.0               3.2
# 37  2019  지역소분류           노원구               56.3               1.6
# 38  2019  지역소분류           은평구               42.7               8.8
# 39  2019  지역소분류          서대문구               69.8               0.8
# 40  2019  지역소분류           마포구               46.6               8.1
# 41  2019  지역소분류           양천구               66.2               5.7
# 42  2019  지역소분류           강서구               38.5               3.8
# 43  2019  지역소분류           구로구               45.3               5.7
# 44  2019  지역소분류           금천구               53.6               2.4
# 45  2019  지역소분류          영등포구               50.2               6.7
# 46  2019  지역소분류           동작구               39.1              13.9
# 47  2019  지역소분류           관악구               44.4               8.8
# 48  2019  지역소분류           서초구               49.9               4.3
# 49  2019  지역소분류           강남구               40.7               4.2
# 50  2019  지역소분류           송파구               47.6               5.0
# 51  2019  지역소분류           강동구               47.0               5.2
#
#     운동을 할 만한 장소가 없어서  운동을 싫어해서  운동을 할 충분한 비용이 없어서    기타
# 0                4.3      37.3                5.2   1.4
# 1                4.9      32.4                4.9   1.1
# 2                3.9      41.0                5.4   1.7
# 3                3.9      32.6                3.5     -
# 4                4.5      38.8                6.4   0.1
# 5                2.9      27.3                4.5   0.2
# 6                2.9      35.5                3.3   0.4
# 7                4.5      36.8                5.6   0.8
# 8                6.6      48.7                6.6   5.6
# 9                4.8      48.6                7.3   8.5
# 10               5.6      38.6                5.5   0.7
# 11               3.3      34.0                4.6   0.3
# 12               5.6      29.0                0.9   0.3
# 13               9.9      50.7                9.4  10.9
# 14               6.0      49.1                7.4   2.3
# 15               3.9      39.5                5.1   1.4
# 16               4.2      35.5                4.8   0.7
# 17               3.3      38.7                5.3   0.2
# 18               4.0      33.4                4.5   1.0
# 19               4.1      37.3                4.6   0.7
# 20               4.0      35.1                5.6   0.2
# 21               5.7      42.4                6.4   6.9
# 22               7.2      28.3                4.0   2.9
# 23               4.1      40.6                5.5   1.8
# 24               5.1      31.4                5.3   0.9
# 25               4.7      35.9                4.8   0.8
# 26               3.1      38.9                5.4   1.5
# 27               9.4      25.9                2.1     -
# 28               7.7      25.7                7.6   5.7
# 29               4.9      32.6                2.7   3.4
# 30               5.7      34.2                8.7   0.6
# 31               3.0      43.5                5.8     -
# 32               2.7      41.9                6.2   0.1
# 33               6.8      32.8               10.9   0.5
# 34               2.6      58.0                2.0   0.7
# 35               3.4      68.1                1.9     -
# 36               6.2      30.8                7.6   0.3
# 37               2.7      30.1                1.9   7.4
# 38               7.3      34.3                6.4   0.5
# 39               1.2      21.9                5.3   1.0
# 40               4.7      35.8                3.2   1.5
# 41               5.9      17.9                4.1   0.1
# 42               1.9      50.5                4.3   1.0
# 43               5.8      39.0                2.9   1.3
# 44               2.3      37.6                2.3   1.7
# 45               3.8      33.9                5.4     -
# 46               8.4      31.1                7.6     -
# 47               5.5      34.2                6.1   1.0
# 48               4.1      36.6                3.3   1.8
# 49               2.0      46.4                5.2   1.6
# 50               2.3      39.4                4.8   1.0
# 51               4.8      32.4                8.4   2.3

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   시점                 52 non-null     int64
#  1   구분별(1)             52 non-null     object
#  2   구분별(2)             52 non-null     object
#  3   운동을 할 충분한 시간이 없어서  52 non-null     float64
#  4   함께 운동을 할 사람이 없어서   52 non-null     float64
#  5   운동을 할 만한 장소가 없어서   52 non-null     float64
#  6   운동을 싫어해서           52 non-null     float64
#  7   운동을 할 충분한 비용이 없어서  52 non-null     float64
#  8   기타                 52 non-null     object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
raw_data[raw_data['구분별(1)'] == '성별']
# Out:
#      시점 구분별(1) 구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 1  2019     성별     남자               52.4               4.4               4.9
# 2  2019     성별     여자               42.5               5.6               3.9
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7

# %%
raw_data.drop(['시점'], axis='columns').head()
# Out:
#   구분별(1) 구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0    서울시     소계               46.8               5.0               4.3
# 1     성별     남자               52.4               4.4               4.9
# 2     성별     여자               42.5               5.6               3.9
# 3    연령별    10대               55.3               4.8               3.9
# 4    연령별    20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
raw_data.drop(['시점'], axis='columns', inplace=True)
raw_data.head()
# Out:
#   구분별(1) 구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0    서울시     소계               46.8               5.0               4.3
# 1     성별     남자               52.4               4.4               4.9
# 2     성별     여자               42.5               5.6               3.9
# 3    연령별    10대               55.3               4.8               3.9
# 4    연령별    20대               46.0               4.2               4.5
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 0      37.3                5.2  1.4
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7
# 3      32.6                3.5    -
# 4      38.8                6.4  0.1

# %%
raw_data = raw_data[raw_data['구분별(1)'] == '성별']
raw_data
# Out:
#   구분별(1) 구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 1     성별     남자               52.4               4.4               4.9
# 2     성별     여자               42.5               5.6               3.9
#
#    운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 1      32.4                4.9  1.1
# 2      41.0                5.4  1.7

# %%
import koreanize_matplotlib
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(6, 4))
raw_data['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02])
plt.show()

# %%
raw_data.set_index('구분별(2)', inplace=True)
raw_data.head()
# Out:
#        구분별(1)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 구분별(2)
# 남자         성별               52.4               4.4               4.9
# 여자         성별               42.5               5.6               3.9
#
#         운동을 싫어해서  운동을 할 충분한 비용이 없어서   기타
# 구분별(2)
# 남자          32.4                4.9  1.1
# 여자          41.0                5.4  1.7

# %%
plt.figure(figsize=(10, 8))
raw_data['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02])
plt.show()

# %%
plt.figure(figsize=(10, 8))
raw_data['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02])
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
len(ax)
# Out:
# 2

# %%
fig, ax = plt.subplots(1,2,figsize=(16,8))
raw_data['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02], ax=ax[0])
raw_data['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02], ax=ax[1])
plt.show()

# %%
f, ax = plt.subplots(1,2,figsize=(16,8))

raw_data['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0,0.02],
                                       ax=ax[0], autopct='%1.1f%%')
ax[0].set_title('운동을 할 충분한 시간이 없어서')
ax[0].set_ylabel('')
raw_data['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0,0.02],
                                      ax=ax[1], autopct='%1.1f%%')
ax[1].set_title('함께 운동을 할 사람이 없어서')
ax[1].set_ylabel('')
plt.show()
