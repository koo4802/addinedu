# %%
import folium

# %%
m = folium.Map(location=[45.5236, -122.6750], zoom_start=15)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map(location=[45.5236, -122.6750], tiles="Cartodb dark_matter", zoom_start=13)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
folium.Map(location=[37.4780333, 126.8790086], tiles="Cartodb Positron", zoom_start=16)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
my_map = folium.Map(location=[37.4780333, 126.8790086], tiles="OpenTopoMap", zoom_start=12)

folium.Marker(location=[37.4816268, 126.8829256], popup="<i>Gasan Digital Complex Station</i>").add_to(my_map)
folium.Marker(location=[37.4780333, 126.8790086], popup="<i>AddinEdu Academy</i>").add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[37.5445649, 127.0558230], zoom_start=10, tiles="OpenTopoMap")

folium.Marker(
    location=[37.54712, 126.964320],
    popup="<b>Subway</b>",
    icon=folium.Icon(color="green")
).add_to(m)

folium.Marker(
    location=[37.544564, 127.05582],
    popup="Subway",
    tooltip="<i>성수역</i>",
    icon=folium.Icon(color="red", icon="cloud")
).add_to(m)

folium.Marker(
    location=[37.477607, 126.880494],
    popup="<a href='https://addinedu.com/' target='_blank'>에드인에듀</a>",
    tooltip="<i>에드인에듀</i>",
    icon=folium.Icon(color="black", icon="info-sign")
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[45.5236, -122.6750], tiles="OpenTopoMap", zoom_start=13)

folium.Circle(
    radius=100,
    location=[45.5244, -122.6699],
    popup="The Waterfront",
    color="crimson",
    fill=False
).add_to(m)

folium.CircleMarker(
    location=[45.5215, -122.6261],
    radius=50,
    popup="Laurelhurst Park",
    color="#3186cc",
    fill=True,
    fill_color="#3186cc"
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m = folium.Map(location=[46.1991, -122.1889], zoom_start=13, tiles="OpenTopoMap")
m.add_child(folium.LatLngPopup())
m

# %%
m.save("../data/index.html")

# %%
import json
import pandas as pd

state_data = pd.read_csv("../data/02. US_Unemployment_Oct2012.csv")

m = folium.Map(location=[48,-102], zoom_start=3)

folium.Choropleth(
    geo_data="../data/02. us-states.json",
    data=state_data,
    columns=["State", "Unemployment"],
    key_on="feature.id",
    fill_color="YlGn",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Unemployment Rate (%)",
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import json

crim_anal_norm = pd.read_csv(
    "../data/crime_result.csv", index_col=0, encoding="utf-8"
)
geo_path = "../data/02. skorea_municipalities_geo_simple.json"
geo_str = json.load(open(geo_path, encoding="utf-8"))

# %%
my_map = folium.Map(location=[37.5502, 126.982], zoom_start=11, tiles="OpenTopoMap")

folium.Choropleth(
    geo_data=geo_str,
    data=crim_anal_norm["성범죄"],
    columns=[crim_anal_norm.index, crim_anal_norm["성범죄"]],
    fill_color="PuRd",
    key_on="feature.id",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="정규화된 성범죄 발생 건수",
).add_to(my_map)

# %%
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import os
os.listdir("../data/crime")
# Out:
# ['2007.csv',
#  '2003.csv',
#  '2017.csv',
#  '2004.csv',
#  '2021.csv',
#  '2011.csv',
#  '2005.csv',
#  '2015.csv',
#  '2012.csv',
#  '2014.csv',
#  '2023.csv',
#  '2009.csv',
#  '2000.csv',
#  '2018.csv',
#  '2016.csv',
#  '2001.csv',
#  '2006.csv',
#  '2002.csv',
#  '2008.csv',
#  '2020.csv',
#  '2022.csv',
#  '2013.csv',
#  '2019.csv',
#  '2010.csv']

# %%
from glob import glob

glob("../data/crime/*")
# Out:
# ['../data/crime/2007.csv',
#  '../data/crime/2003.csv',
#  '../data/crime/2017.csv',
#  '../data/crime/2004.csv',
#  '../data/crime/2021.csv',
#  '../data/crime/2011.csv',
#  '../data/crime/2005.csv',
#  '../data/crime/2015.csv',
#  '../data/crime/2012.csv',
#  '../data/crime/2014.csv',
#  '../data/crime/2023.csv',
#  '../data/crime/2009.csv',
#  '../data/crime/2000.csv',
#  '../data/crime/2018.csv',
#  '../data/crime/2016.csv',
#  '../data/crime/2001.csv',
#  '../data/crime/2006.csv',
#  '../data/crime/2002.csv',
#  '../data/crime/2008.csv',
#  '../data/crime/2020.csv',
#  '../data/crime/2022.csv',
#  '../data/crime/2013.csv',
#  '../data/crime/2019.csv',
#  '../data/crime/2010.csv']

# %%
target_path = "../data/crime/"
file_list = glob(target_path + "20*.csv")
file_list
# Out:
# ['../data/crime/2007.csv',
#  '../data/crime/2003.csv',
#  '../data/crime/2017.csv',
#  '../data/crime/2004.csv',
#  '../data/crime/2021.csv',
#  '../data/crime/2011.csv',
#  '../data/crime/2005.csv',
#  '../data/crime/2015.csv',
#  '../data/crime/2012.csv',
#  '../data/crime/2014.csv',
#  '../data/crime/2023.csv',
#  '../data/crime/2009.csv',
#  '../data/crime/2000.csv',
#  '../data/crime/2018.csv',
#  '../data/crime/2016.csv',
#  '../data/crime/2001.csv',
#  '../data/crime/2006.csv',
#  '../data/crime/2002.csv',
#  '../data/crime/2008.csv',
#  '../data/crime/2020.csv',
#  '../data/crime/2022.csv',
#  '../data/crime/2013.csv',
#  '../data/crime/2019.csv',
#  '../data/crime/2010.csv']

# %%
for each in file_list:
    print(each)
# Out:
# ../data/crime/2007.csv
# ../data/crime/2003.csv
# ../data/crime/2017.csv
# ../data/crime/2004.csv
# ../data/crime/2021.csv
# ../data/crime/2011.csv
# ../data/crime/2005.csv
# ../data/crime/2015.csv
# ../data/crime/2012.csv
# ../data/crime/2014.csv
# ../data/crime/2023.csv
# ../data/crime/2009.csv
# ../data/crime/2000.csv
# ../data/crime/2018.csv
# ../data/crime/2016.csv
# ../data/crime/2001.csv
# ../data/crime/2006.csv
# ../data/crime/2002.csv
# ../data/crime/2008.csv
# ../data/crime/2020.csv
# ../data/crime/2022.csv
# ../data/crime/2013.csv
# ../data/crime/2019.csv
# ../data/crime/2010.csv

# %%
import pandas as pd
import numpy as np

crime_raw_data = pd.read_csv(file_list[0], usecols=[0,1,2,3], encoding="euc-kr")
crime_raw_data["죄종"] = crime_raw_data["죄종"].replace("강간,추행", "강간")

crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index=["구분"], columns=["죄종", "발생검거"], aggfunc="sum"
)

crime_station.columns = [
    "강간검거",
    "강간",
    "강도검거",
    "강도",
    "살인검거",
    "살인",
    "절도검거",
    "절도",
    "폭행검거",
    "폭행",
]

crime_station["year"] = 2000
crime_station.head()
# Out:
#      강간검거     강간  강도검거    강도  살인검거    살인   절도검거      절도    폭행검거      폭행  year
# 구분
# 강남  131.0  160.0  45.0  66.0   4.0   8.0  579.0   865.0  2975.0  3117.0  2000
# 강동   96.0  102.0  40.0  35.0   9.0   7.0  931.0   814.0  2789.0  2791.0  2000
# 강북  104.0  130.0  51.0  46.0  12.0  12.0  578.0   740.0  2360.0  2373.0  2000
# 강서  124.0  131.0  64.0  53.0   3.0   4.0  751.0  1358.0  3058.0  3274.0  2000
# 관악  136.0  236.0  73.0  87.0  10.0  13.0  766.0  1774.0  3407.0  3693.0  2000

# %%
for each in file_list:
    print(each.split("/")[-1].split(".")[0])
# Out:
# 2007
# 2003
# 2017
# 2004
# 2021
# 2011
# 2005
# 2015
# 2012
# 2014
# 2023
# 2009
# 2000
# 2018
# 2016
# 2001
# 2006
# 2002
# 2008
# 2020
# 2022
# 2013
# 2019
# 2010

# %%
crime_station_t = []
for each in file_list:
    crime_raw_data = pd.read_csv(each, usecols=[0,1,2,3], encoding="euc-kr")
    crime_raw_data["죄종"] = crime_raw_data["죄종"].replace("강간,추행", "강간")

    crime_station = crime_raw_data.pivot_table(
    crime_raw_data, index=["구분"], columns=["죄종", "발생검거"], aggfunc="sum"
)

    crime_station.columns = [
    "강간검거",
    "강간",
    "강도검거",
    "강도",
    "살인검거",
    "살인",
    "절도검거",
    "절도",
    "폭행검거",
    "폭행",
]

    crime_station["year"] = each.split("/")[-1].split(".")[0]
    crime_station_t.append(crime_station)

# %%
crime_total = pd.concat(crime_station_t)
crime_total.head()
# Out:
#      강간검거     강간  강도검거    강도  살인검거    살인   절도검거      절도    폭행검거      폭행  year
# 구분
# 강남  131.0  160.0  45.0  66.0   4.0   8.0  579.0   865.0  2975.0  3117.0  2007
# 강동   96.0  102.0  40.0  35.0   9.0   7.0  931.0   814.0  2789.0  2791.0  2007
# 강북  104.0  130.0  51.0  46.0  12.0  12.0  578.0   740.0  2360.0  2373.0  2007
# 강서  124.0  131.0  64.0  53.0   3.0   4.0  751.0  1358.0  3058.0  3274.0  2007
# 관악  136.0  236.0  73.0  87.0  10.0  13.0  766.0  1774.0  3407.0  3693.0  2007

# %%
crime_total_murder = crime_total.pivot_table(index="year", columns="구분", values="살인")
crime_total_murder
# Out:
# 구분      강남    강동    강북    강서    관악    광진    구로    금천  남대문    노원  ...    수서  \
# year                                                             ...
# 2000   3.0  12.0   9.0   6.0   8.0   2.0  10.0  10.0  3.0   3.0  ...   3.0
# 2001  13.0   9.0   6.0  16.0   3.0  14.0   4.0  13.0  6.0   8.0  ...   4.0
# 2002   3.0   6.0   7.0   8.0   8.0  12.0   4.0  16.0  2.0   7.0  ...   7.0
# 2003   7.0   6.0   9.0   5.0   4.0   6.0   6.0  15.0  2.0   3.0  ...   5.0
# 2004   8.0   7.0  15.0   8.0   0.0  10.0  13.0  16.0  1.0   5.0  ...   6.0
# 2005   8.0   5.0  10.0  10.0   5.0  16.0  10.0  14.0  1.0  10.0  ...   5.0
# 2006   5.0   4.0   5.0  16.0   5.0   7.0  16.0   5.0  2.0   6.0  ...   4.0
# 2007   8.0   7.0  12.0   4.0  13.0   8.0  19.0   6.0  0.0  11.0  ...   4.0
# 2008  10.0   8.0   7.0  18.0  10.0   3.0  22.0   3.0  1.0   3.0  ...   3.0
# 2009  10.0   6.0   7.0  10.0  11.0  11.0  16.0   7.0  2.0  12.0  ...   7.0
# 2010  12.0  18.0   7.0   7.0  13.0  11.0  17.0   8.0  3.0  16.0  ...   2.0
# ...

# %%
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
import seaborn as sns

plt.figure(figsize=(10, 8))
sns.heatmap(crime_total_murder, annot=True, linewidths=0.5, cmap="RdPu")
plt.title("2000년부터 2023년 서울시 구별 살인 사건의 수")
plt.autoscale()
plt.tight_layout(pad=5)
plt.show()

# %%
crime_total_murder.plot(figsize=(12,10))
plt.show()

# %%
crime_total_murder[["강남", "서초", "영등포"]].plot(figsize=(12,10))
plt.show()

# %%
crime_total_violence = crime_total.pivot_table(index="year", columns="구분", values="폭행")
crime_total_violence[["강남","서초","영등포","노원","관악"]].plot(figsize=(12,10))
plt.show()

# %%
crime_total_sexual = crime_total.pivot_table(index="year", columns="구분", values="강간")
crime_total_sexual[["강남","서초","영등포","노원","관악"]].plot(figsize=(12,10))
plt.show()
